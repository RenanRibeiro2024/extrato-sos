# %%
import pandas as pd
# Out:
# Running cells with 'extrato-sos-py3.13 (Python 3.13.9)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/ribei/Desktop/Cursos/VsCode/Projetos/extrato_SOS/.venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'
