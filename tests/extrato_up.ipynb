# %%
import streamlit as st

#______________________________________________________________ Configuração da página
st.set_page_config(page_title="extrato-sos", layout="wide")
st.title("📊 Extrato-SOS - Análise Financeira de Extratos")

#______________________________________________________________ Inicializa session state para armazenar os extratos
if "extratos" not in st.session_state:
    st.session_state["extratos"] = {}

#______________________________________________________________  Upload dos arquivos
uploaded_files = st.file_uploader("📎 Carregue uma ou mais faturas (CSV ou Excel)", type=["csv", "xls", "xlsx"], accept_multiple_files=True)

if uploaded_files:
    for uploaded_file in uploaded_files:
        nome_arquivo = uploaded_file.name


        with st.expander(f"📄 {nome_arquivo}", expanded=True):
            layout = st.selectbox("Layout da fatura", ["Nubank", "Banco Inter"], key=f"layout_{nome_arquivo}")

            vencimento = st.date_input(
                "📅 Data de vencimento da fatura",
                key=f"vencimento_{nome_arquivo}"
            )
# Out:
# 2025-12-04 01:54:24.672 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-04 01:54:24.673 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-04 01:54:25.042
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run c:\Users\ribei\Desktop\Cursos\VsCode\Repositorios\extrato_SOS\.venv\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2025-12-04 01:54:25.042 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-04 01:54:25.043 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-04 01:54:25.044 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-04 01:54:25.044 Session state does not function when running a script without `streamlit run`
# 2025-12-04 01:54:25.045 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-04 01:54:25.045 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-04 01:54:25.045 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-04 01:54:25.046 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-04 01:54:25.046 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-04 01:54:25.047 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-04 01:54:25.048 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-04 01:54:25.048 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
